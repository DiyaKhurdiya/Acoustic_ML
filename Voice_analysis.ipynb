# %%
import os
from matplotlib import pyplot as plt
import librosa
import librosa.display
# %matplotlib inline

import IPython.display as ipd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/train.zip"
# Out:
# unzip:  cannot find or open /content/train.zip, /content/train.zip.zip or /content/train.zip.ZIP.

# %%
audio_path = "/1620627399144-recording-1.wav"

# %%
x, sr = librosa.load(audio_path, sr=44100)

print(type(x), type(sr))
print(x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (22050,) 44100

# %%
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr, color='green')
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.show()

# %%
audio_path1 = "/1621248471058-recording-1.wav"

# %%
y, sr = librosa.load(audio_path1, sr=44100)

print(type(y), type(sr))
print(y.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (22050,) 44100

# %%
ipd.Audio(audio_path1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr, color='red')
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# Mel spectrogram for tb_0

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))

plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %% [markdown]
# Mel spectrogram for tb_1

# %%
Y = librosa.stft(y)
Ydb = librosa.amplitude_to_db(abs(Y))

plt.figure(figsize=(14, 5))
librosa.display.specshow(Ydb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
from scipy import signal
import random


def f_high(y,sr):
    b,a = signal.butter(10, 2000/(sr/2), btype='highpass')
    yf = signal.lfilter(b,a,y)
    return yf

# %%
yf0 = f_high(x,sr)
yf1 = f_high(y,sr)

# %%
from IPython.display import Audio, IFrame, display
display(Audio(yf0, rate=sr))
display(Audio(yf1,rate=sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
